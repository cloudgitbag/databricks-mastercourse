# %% [markdown]
# #### This is my first notebook

# %%
class TestClass():
    def test_1(self):
        assert True

    def test_3(self):
        assert 4 == 3

def test_foo():
    assert "foo" == "bar"
#https://docs.databricks.com/aws/en/files/python-unit-tests
