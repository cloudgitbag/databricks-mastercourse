# %%
# %run ./02-setup

# %%
SH = SetupHelper("masterdb_dev")
#SH.cleanup()

# %%
SH.setup()

# %%
SH.validate()

# %%
# %run ./03-history-loader

# %%
HL = HistoryLoader("masterdb_dev")
HL.load_history()

# %%
HL.validate()

# %%
# %run ./04-bronze

# %%
BZ = Bronze("masterdb_dev")

# %%
# input_file_name is unsupported in Unity Catalog, use _metadata.file_path instead
BZ.consume()
